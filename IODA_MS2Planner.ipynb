# %% [markdown]
# # <span style="color:red"> MS2Planner-from-mzML notebook </span>
#
# **Purpose**: Run PathFinder in all modes
#
#
# **Usage**: Select the data and run the cells

# %% [markdown]
# # SELECT WHICH DATA YOU WANNA TRY

# %% [markdown]
# ## 1) Euphorbia data

# %%
# Blank sample
input_BLANK = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML"
# Reference sample
input_SAMPLE = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML"

input_BLANK = 'Euphorbia_Blank_MS1_5uL.mzML'
input_SAMPLE = 'Euphorbia_MS1_5uL.mzML'

# %% [markdown]
# ## 2) SA113 Test data

# %%
# Blank sample
input_BLANK = "tests/BP_mzTab/SA113_SPE_MeOH_MS1.mzML"
# Reference sample
input_SAMPLE = "tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1.mzML"

# %% [markdown]
# ## 3) Disolved Organic Matter via Google Drive

# %%
input_BLANK = "https://drive.google.com/file/d/10A1XZhcKCVXIKf4v7aLX0tNYM011qV_Z/view?usp=sharing"
# Reference sample
input_SAMPLE = "https://drive.google.com/file/d/1CoKzvreEgT0mq4JEBuB-2T0VFfoHFhZT/view?usp=sharing"

# %%
# OpenMS FeatureFinderMetabolomics parameters
ppm_error = 10
noise_level = 5E6

# %%
from IODA_run_OpenMS_targeted import *
IODA_targeted_workflow(input_BLANK,input_SAMPLE,ppm_error,noise_level)
# Out:
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:40] 2020-08-27 23:16:02.074543
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:41] STARTING the IODA-targeted WORKFLOW
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:42] ======
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:43] Path to the input files:
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:44] Blank: Euphorbia_Blank_MS1_5uL.mzML
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:45] Sample: Euphorbia_MS1_5uL.mzML
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:96] Copying the mzML files ...
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:83] Path to uploaded file: Euphorbia_Blank_MS1_5uL.mzML
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:83] Path to uploaded file: Euphorbia_MS1_5uL.mzML
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:100] ======
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:101] Changing the variables of the OpenMS workflow ...
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:102]    ppm error = 10
# [I 200827 23:16:02 IODA_run_OpenMS_targeted:103]    noise threshold = 5.00e+06
# [I 200827 23:16:06 IODA_run_OpenMS_targeted:145] ======
# [I 200827 23:16:06 IODA_run_OpenMS_targeted:146] Initializing the OpenMS workflow
# [I 200827 23:16:07 IODA_run_OpenMS_targeted:154] ======
# [I 200827 23:16:07 IODA_run_OpenMS_targeted:155] Running the OpenMS workflow, this usually takes less than a minute, please wait ...
# [I 200827 23:16:07 IODA_run_OpenMS_targeted:156] If this takes longer, increase the noise treshold value ...
# [I 200827 23:16:10 IODA_run_OpenMS_targeted:182] ======
# [I 200827 23:16:10 IODA_run_OpenMS_targeted:183] Completed the OpenMS workflow
# [I 200827 23:16:10 IODA_run_OpenMS_targeted:184] ======
# [I 200827 23:16:10 IODA_run_OpenMS_targeted:185] Zipping up the OpenMS workflow results ..
# [I 200827 23:16:11 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 200827 23:16:11 IODA_run_OpenMS_targeted:188] ======
# [I 200827 23:16:11 IODA_run_OpenMS_targeted:189] Completed zipping up the OpenMS workflow result files
# [I 200827 23:16:11 IODA_run_OpenMS_targeted:191] ======
# [I 200827 23:16:11 IODA_run_OpenMS_targeted:192] NOW CONTINUE WITH THE REST OF THE IODA-targeted WORKFLOW

# %% [markdown]
# ## Run MS2Planner

# %%
from IODA_MS2Planner_workflow import *

# %% [markdown]
# ### Shared parameters for the modes (baseline/apex/curve)

# %%
# Best Path shared parameters
min_ratio_value = 1
min_intensity_value = 0 #1E4
experiment_number = 3
isolation = 1.5
delay = 0.0 #sec

# Target ion list parameters
rt_margin = 1 #sec

# %% [markdown]
# ### MS2Planner in Baseline mode

# %%
# Baseline parameter
win_len = 0.2 #sec (duration of scan)

# %%
# Run Path Finder with Baseline method 
run_MS2Planner_baseline_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value,\
                                   min_intensity_value, win_len, isolation, delay, \
                                   rt_margin)
# Out:
# [I 200827 23:35:04 IODA_MS2Planner_workflow:131] STARTING THE MS2Planner WORKFLOW
# [I 200827 23:35:04 IODA_MS2Planner_workflow:136] The mzTab was generated with the IODA-OpenMS workflow
# [I 200827 23:35:04 IODA_MS2Planner_workflow:144] 2020-08-27 23:35:04.337602
# [I 200827 23:35:04 IODA_MS2Planner_workflow:146] ======
# [I 200827 23:35:04 IODA_MS2Planner_workflow:147] Getting the mzTab
# [I 200827 23:35:04 IODA_MS2Planner_workflow:163] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.mzTab
# [I 200827 23:35:04 IODA_MS2Planner_workflow:164] This is the output file path: results_targeted_MS2Planner_baseline/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.csv
# [I 200827 23:35:04 IODA_MS2Planner_workflow:168] ======
# [I 200827 23:35:04 IODA_MS2Planner_workflow:169] Converting mzTab to intermediate table format ...
# [I 200827 23:35:04 IODA_MS2Planner_workflow:76] - For sample Euphorbia_Blank_MS1_5uL the sum of feature intensities is = 1.20e+07
# [I 200827 23:35:04 IODA_MS2Planner_workflow:78] - For sample Euphorbia_MS1_5uL the sum of feature intensities = 4.66e+10
# [I 200827 23:35:04 IODA_MS2Planner_workflow:171] ======
# [I 200827 23:35:04 IODA_MS2Planner_workflow:176] Assumed sample filename: Euphorbia_MS1_5uL
# [I 200827 23:35:04 IODA_MS2Planner_workflow:178] Assumed blank filename: Euphorbia_Blank_MS1_5uL
# [I 200827 23:35:04 IODA_MS2Planner_workflow:179] ======
# [I 200827 23:35:04 IODA_MS2Planner_workflow:182] User-defined parameters
# [I 200827 23:35:04 IODA_MS2Planner_workflow:184]     Ratio between sample/blank for ion filtering = 1
# [I 200827 23:35:04 IODA_MS2Planner_workflow:186]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 200827 23:35:04 IODA_MS2Planner_workflow:187]     Retention time window (min.) for binning target ions = 0.2
# [I 200827 23:35:04 IODA_MS2Planner_workflow:188]     Isolation window (m/z) = 1.5
# [I 200827 23:35:04 IODA_MS2Planner_workflow:189]     Retention time margin (sec.) = 0.0
# [I 200827 23:35:04 IODA_MS2Planner_workflow:191]     Number of iterative experiment(s) = 3
# [I 200827 23:35:04 IODA_MS2Planner_workflow:192] User-defined parameters for the output
# [I 200827 23:35:04 IODA_MS2Planner_workflow:193]     Retention time margin for target ion list (secs.) = 1
# [I 200827 23:35:04 IODA_MS2Planner_workflow:194] ======
# [I 200827 23:35:04 IODA_MS2Planner_workflow:197] Running MS2Planner in Baseline mode ...
# [I 200827 23:35:04 IODA_MS2Planner_workflow:682] Command: python3 path_finder.py baseline results_targeted_MS2Planner_baseline/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.csv results_targeted_MS2Planner_baseline/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd_MS2Planner.csv 0 1 3 -win_len 0.2 -isolation 1.5 -delay 0.0
# [I 200827 23:35:05 IODA_MS2Planner_workflow:213] ======
# [I 200827 23:35:05 IODA_MS2Planner_workflow:217] 2020-08-27 23:35:05,412 - path_finder - INFO - =============
#     2020-08-27 23:35:05,412 - path_finder - INFO - Baseline mode begin
#     2020-08-27 23:35:05,412 - path_finder - INFO - =============
#     2020-08-27 23:35:05,412 - path_finder - INFO - File Read
#     2020-08-27 23:35:05,412 - path_finder - INFO - =============
#     2020-08-27 23:35:05,412 - path_finder - INFO - Begin Finding Path
#     2020-08-27 23:35:05,412 - path_finder - INFO - =============
#     2020-08-27 23:35:05,429 - path_finder - INFO - Paths Generated
#     2020-08-27 23:35:05,429 - path_finder - INFO - =============
#     2020-08-27 23:35:05,431 - path_finder - INFO - File Written
#     2020-08-27 23:35:05,431 - path_finder - INFO - =============
#
# [I 200827 23:35:05 IODA_MS2Planner_workflow:222] MS2Planner Path output found
# [I 200827 23:35:05 IODA_MS2Planner_workflow:231] Preparing results ...
# [I 200827 23:35:05 IODA_MS2Planner_workflow:644] File processed: results_targeted_MS2Planner_baseline/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd_MS2Planner.csv
# [I 200827 23:35:05 IODA_MS2Planner_workflow:645] ======
# [I 200827 23:35:05 IODA_MS2Planner_workflow:637] Valid target ions in path1 = 211
# [I 200827 23:35:05 IODA_MS2Planner_workflow:654] Formatting to XCalibur format ...
# [I 200827 23:35:05 IODA_MS2Planner_workflow:657] Formatting for MaxQuant.Live ...
# [I 200827 23:35:05 IODA_MS2Planner_workflow:660] =======
# [I 200827 23:35:05 IODA_MS2Planner_workflow:669] results_targeted_MS2Planner_baseline
# [I 200827 23:35:07 IODA_MS2Planner_workflow:234] ======
# [I 200827 23:35:07 IODA_MS2Planner_workflow:236] Cleaning and zipping workflow results files ...
# [I 200827 23:35:08 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 200827 23:35:08 IODA_MS2Planner_workflow:264] ======
# [I 200827 23:35:08 IODA_MS2Planner_workflow:265] END OF THE MS2Planner WORKFLOW
# [I 200827 23:35:08 IODA_MS2Planner_workflow:266] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Apex mode

# %%
# Apex parameters
intensity_accu = 3e4
min_scan = 0.1
max_scan = 1
delay = 0.05

rt_margin = 1
transient = 100

# %%
# Run Path Finder with Apex method
run_MS2Planner_apex_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, intensity_accu, isolation, delay, min_scan, max_scan, rt_margin, transient)
# Out:
# [I 200827 23:36:25 IODA_MS2Planner_workflow:281] STARTING THE MS2Planner WORKFLOW
# [I 200827 23:36:25 IODA_MS2Planner_workflow:286] The mzTab was generated with the IODA-OpenMS workflow
# [I 200827 23:36:25 IODA_MS2Planner_workflow:294] 2020-08-27 23:36:25.314862
# [I 200827 23:36:25 IODA_MS2Planner_workflow:296] ======
# [I 200827 23:36:25 IODA_MS2Planner_workflow:297] Getting the mzTab
# [I 200827 23:36:25 IODA_MS2Planner_workflow:313] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.mzTab
# [I 200827 23:36:25 IODA_MS2Planner_workflow:314] This is the output file path: results_targeted_MS2Planner_apex/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.csv
# [I 200827 23:36:25 IODA_MS2Planner_workflow:318] ======
# [I 200827 23:36:25 IODA_MS2Planner_workflow:319] Converting mzTab to intermediate table format ...
# [I 200827 23:36:25 IODA_MS2Planner_workflow:76] - For sample Euphorbia_Blank_MS1_5uL the sum of feature intensities is = 1.20e+07
# [I 200827 23:36:25 IODA_MS2Planner_workflow:78] - For sample Euphorbia_MS1_5uL the sum of feature intensities = 4.66e+10
# [I 200827 23:36:25 IODA_MS2Planner_workflow:321] ======
# [I 200827 23:36:25 IODA_MS2Planner_workflow:326] Assumed sample filename: Euphorbia_MS1_5uL
# [I 200827 23:36:25 IODA_MS2Planner_workflow:328] Assumed blank filename: Euphorbia_Blank_MS1_5uL
# [I 200827 23:36:25 IODA_MS2Planner_workflow:329] ======
# [I 200827 23:36:25 IODA_MS2Planner_workflow:332] User-defined parameters
# [I 200827 23:36:25 IODA_MS2Planner_workflow:334]     Ratio between sample/blank for ion filtering = 1
# [I 200827 23:36:25 IODA_MS2Planner_workflow:336]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 200827 23:36:25 IODA_MS2Planner_workflow:337]     Precursor ion intensity to accumulate in the MS2 scan = 1.00e+03
# [I 200827 23:36:25 IODA_MS2Planner_workflow:338]     Isolation window (m/z) = 1.5
# [I 200827 23:36:25 IODA_MS2Planner_workflow:339]     Delay between targeted MS2 scans (sec.)= 0.05
# [I 200827 23:36:25 IODA_MS2Planner_workflow:340]     Minimum MS2 scan duty cycle (sec.)= 0.1
# [I 200827 23:36:25 IODA_MS2Planner_workflow:341]     Maximum MS2 scan duty cycle (sec.)= 1
# [I 200827 23:36:25 IODA_MS2Planner_workflow:343]     Number of iterative experiment(s) = 3
# [I 200827 23:36:25 IODA_MS2Planner_workflow:344] User-defined parameters for the output
# [I 200827 23:36:25 IODA_MS2Planner_workflow:345]     Retention time margin for target ion list (secs.) = 1
# [I 200827 23:36:25 IODA_MS2Planner_workflow:346]     Orbitrap transient + overhead time for MaxQuant.Live (secs) = 100
# [I 200827 23:36:25 IODA_MS2Planner_workflow:348] ======
# [I 200827 23:36:25 IODA_MS2Planner_workflow:351] Running MS2Planner in Apex mode ...
# [I 200827 23:36:25 IODA_MS2Planner_workflow:687] Command: python3 path_finder.py apex results_targeted_MS2Planner_apex/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd.csv results_targeted_MS2Planner_apex/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd_MS2Planner.csv 0 1 3 -intensity_accu 1000.0 -isolation 1.5 -delay 0.05 -min_scan 0.1 -max_scan 1
# [I 200827 23:36:26 IODA_MS2Planner_workflow:368] ======
# [I 200827 23:36:26 IODA_MS2Planner_workflow:372] 2020-08-27 23:36:26,545 - path_finder - INFO - =============
#     2020-08-27 23:36:26,545 - path_finder - INFO - Apex mode begin
#     2020-08-27 23:36:26,545 - path_finder - INFO - =============
#     2020-08-27 23:36:26,545 - path_finder - INFO - File Read
#     2020-08-27 23:36:26,545 - path_finder - INFO - =============
#     2020-08-27 23:36:26,545 - path_finder - INFO - Begin Finding Path
#     2020-08-27 23:36:26,545 - path_finder - INFO - =============
#     2020-08-27 23:36:26,564 - path_finder.apex - INFO - [1/3]: features: 193, rest: 364
#     2020-08-27 23:36:26,566 - path_finder.apex - INFO - [2/3]: features: 78, rest: 171
#     2020-08-27 23:36:26,568 - path_finder.apex - INFO - [3/3]: features: 37, rest: 93
#     2020-08-27 23:36:26,568 - path_finder - INFO - Paths Generated
#     2020-08-27 23:36:26,568 - path_finder - INFO - =============
#     2020-08-27 23:36:26,571 - path_finder - INFO - File Written
#     2020-08-27 23:36:26,571 - path_finder - INFO - =============
#
# [I 200827 23:36:26 IODA_MS2Planner_workflow:374] ======
# [I 200827 23:36:26 IODA_MS2Planner_workflow:379] MS2Planner output found
# [I 200827 23:36:26 IODA_MS2Planner_workflow:389] Preparing results ...
# [I 200827 23:36:26 IODA_MS2Planner_workflow:644] File processed: results_targeted_MS2Planner_apex/Euphorbia_Blank_MS1_5uL_to_Euphorbia_MS1_5uL_mrgd_MS2Planner.csv
# [I 200827 23:36:26 IODA_MS2Planner_workflow:645] ======
# [I 200827 23:36:26 IODA_MS2Planner_workflow:637] Valid target ions in path1 = 193
# [I 200827 23:36:26 IODA_MS2Planner_workflow:654] Formatting to XCalibur format ...
# [I 200827 23:36:26 IODA_MS2Planner_workflow:657] Formatting for MaxQuant.Live ...
# [I 200827 23:36:26 IODA_MS2Planner_workflow:660] =======
# [I 200827 23:36:26 IODA_MS2Planner_workflow:637] Valid target ions in path2 = 78
# [I 200827 23:36:26 IODA_MS2Planner_workflow:654] Formatting to XCalibur format ...
# [I 200827 23:36:26 IODA_MS2Planner_workflow:657] Formatting for MaxQuant.Live ...
# [I 200827 23:36:26 IODA_MS2Planner_workflow:660] =======
# [I 200827 23:36:27 IODA_MS2Planner_workflow:637] Valid target ions in path3 = 37
# [I 200827 23:36:27 IODA_MS2Planner_workflow:654] Formatting to XCalibur format ...
# [I 200827 23:36:27 IODA_MS2Planner_workflow:657] Formatting for MaxQuant.Live ...
# [I 200827 23:36:27 IODA_MS2Planner_workflow:660] =======
# [I 200827 23:36:27 IODA_MS2Planner_workflow:669] results_targeted_MS2Planner_apex
# [I 200827 23:36:30 IODA_MS2Planner_workflow:391] ======
# [I 200827 23:36:30 IODA_MS2Planner_workflow:393] Cleaning and zipping workflow results files ...
# [I 200827 23:36:30 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 200827 23:36:30 IODA_MS2Planner_workflow:421] ======
# [I 200827 23:36:30 IODA_MS2Planner_workflow:422] END OF THE MS2Planner WORKFLOW
# [I 200827 23:36:30 IODA_MS2Planner_workflow:423] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Curve mode

# %%
MS2Planner_Curve_OpenMS(input_SAMPLE,ppm_error,noise_level)

# %%
# Curve parameters
rt_tolerance_curve = 2 
mz_tolerance_curve = 0.02
intensity_accu = 4e5
min_scan = 0.1
max_scan = 1
delay = 0.05
isolation = 2 

# Target ion list parameters
rt_margin = 1
transient_time = 0.1 #ms

# %%
# Run Path Finder with Curve method
from IODA_MS2Planner_workflow import *
run_MS2Planner_curve_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, 'OpenMS_generated', intensity_accu, rt_tolerance_curve, mz_tolerance_curve, isolation, delay, min_scan, max_scan, rt_margin, transient_time)

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/scatter_plot_duration.png")
