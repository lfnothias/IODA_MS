# %% [markdown]
# # <span style="color:red"> MS2Planner-from-mzML notebook </span>
#
# **Purpose**: Run PathFinder in all modes
#
#
# **Usage**: Select the data and run the cells

# %% [markdown]
# # SELECT WHICH DATA YOU WANNA TRY

# %% [markdown]
# ## 1) Euphorbia data

# %%
# Blank sample
input_BLANK = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML"
# Reference sample
input_SAMPLE = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML"
# OpenMS results
input_mzTab = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab'
input_filename_curve = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Euphorbia_rogers_latex_latex_MS1_2uL.mzTab'

# %% [markdown]
# ## 2) SA113 Test data

# %%
# Blank sample
input_BLANK = "tests/BP_mzTab/SA113_SPE_MeOH_MS1.mzML"
# Reference sample
input_SAMPLE = "tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1.mzML"
# OpenMS results
input_mzTab = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/SA113_SPE_MeOH_MS1_to_SA113_Media_SPE_MeOH_MS1_mrgd.mzTab'
input_filename_curve = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/SA113_Media_SPE_MeOH_MS1.mzTab'

# %% [markdown]
# ## 3) Disolved Organic Matter via Google Drive

# %%
input_BLANK = "https://drive.google.com/file/d/10A1XZhcKCVXIKf4v7aLX0tNYM011qV_Z/view?usp=sharing"
# Reference sample
input_SAMPLE = "https://drive.google.com/file/d/1CoKzvreEgT0mq4JEBuB-2T0VFfoHFhZT/view?usp=sharing"
# OpenMS results
input_mzTab = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Blank_to_Sample_mrgd.mzTab'
input_filename_curve = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Sample.mzTab'

# %%
# OpenMS FeatureFinderMetabolomics parameters
ppm_error = 10
noise_level = 1E6

# %%
from IODA_run_OpenMS_targeted import *
IODA_targeted_workflow(input_BLANK,input_SAMPLE,ppm_error,noise_level)
# Out:
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:40] 2020-08-21 18:29:14.085562
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:41] STARTING the IODA-targeted WORKFLOW
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:42] ======
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:43] Path to the input files:
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:44] Blank: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:45] Sample: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:96] Copying the mzML files ...
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:100] ======
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:101] Changing the variables of the OpenMS workflow ...
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:102]    ppm error = 10
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:103]    noise threshold = 1.00e+06
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:145] ======
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:146] Initializing the OpenMS workflow
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:154] ======
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:155] Running the OpenMS workflow, this usually takes less than a minute, please wait ...
# [I 200821 18:29:14 IODA_run_OpenMS_targeted:156] If this takes longer, increase the noise treshold value ...
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:182] ======
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:183] Completed the OpenMS workflow
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:184] ======
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:185] Zipping up the OpenMS workflow results ..
# [I 200821 18:29:21 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:188] ======
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:189] Completed zipping up the OpenMS workflow result files
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:191] ======
# [I 200821 18:29:21 IODA_run_OpenMS_targeted:192] NOW CONTINUE WITH THE REST OF THE IODA-targeted WORKFLOW

# %% [markdown]
# ## Run MS2Planner

# %%
from IODA_MS2Planner_workflow import *

# %% [markdown]
# ### Shared parameters for the modes (baseline/apex/curve)

# %%
# Best Path shared parameters
min_ratio_value = 5
min_intensity_value = 1E4
experiment_number = 3
isolation = 1.5
delay = 0.1 #sec

# Target ion list parameters
rt_margin = 0.3

# %% [markdown]
# ### MS2Planner in Baseline mode

# %%
# Baseline parameter
win_len = 0.35

# %%
# Run Path Finder with Baseline method 
run_MS2Planner_baseline_from_mzTab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value, win_len, isolation, rt_margin)
# Out:
# [I 200821 18:29:38 IODA_BestPath_workflow:131] STARTING THE PathFinder WORKFLOW
# [I 200821 18:29:38 IODA_BestPath_workflow:141] the input_filename variable should be a valid path/download link or must be: 'OpenMS_generated', when using the OpenMS workflow online
# [I 200821 18:29:38 IODA_BestPath_workflow:144] 2020-08-21 18:29:38.171543
# [I 200821 18:29:38 IODA_BestPath_workflow:146] ======
# [I 200821 18:29:38 IODA_BestPath_workflow:147] Getting the mzTab
# [I 200821 18:29:38 IODA_BestPath_workflow:163] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 200821 18:29:38 IODA_BestPath_workflow:164] This is the output file path: results_targeted_pathfinder_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 200821 18:29:38 IODA_BestPath_workflow:168] ======
# [I 200821 18:29:38 IODA_BestPath_workflow:169] Converting mzTab to intermediate table format ...
# [I 200821 18:29:38 IODA_BestPath_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 5.65e+08
# [I 200821 18:29:38 IODA_BestPath_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.63e+10
# [I 200821 18:29:38 IODA_BestPath_workflow:171] ======
# [I 200821 18:29:38 IODA_BestPath_workflow:176] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 200821 18:29:38 IODA_BestPath_workflow:178] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 200821 18:29:38 IODA_BestPath_workflow:179] ======
# [I 200821 18:29:38 IODA_BestPath_workflow:182] User-defined parameters
# [I 200821 18:29:38 IODA_BestPath_workflow:184]     Ratio between sample/blank for ion filtering = 5
# [I 200821 18:29:38 IODA_BestPath_workflow:186]     Minimum intensity for ion filtering in sample = 1.00e+04
# [I 200821 18:29:38 IODA_BestPath_workflow:187]     Retention time window (min.) for binning target ions = 0.35
# [I 200821 18:29:38 IODA_BestPath_workflow:188]     Isolation window (m/z) = 1.5
# [I 200821 18:29:38 IODA_BestPath_workflow:189]     Retention time margin (sec.) = 0.3
# [I 200821 18:29:38 IODA_BestPath_workflow:191]     Number of iterative experiment(s) = 3
# [I 200821 18:29:38 IODA_BestPath_workflow:192] ======
# [I 200821 18:29:38 IODA_BestPath_workflow:195] Running Path Finder in Baseline mode ...
# [I 200821 18:29:38 IODA_BestPath_workflow:602] Command: python3 path_finder.py baseline results_targeted_pathfinder_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_pathfinder_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_PathFinder.csv 10000.0 5 3 -win_len 0.35 -isolation 1.5
# [I 200821 18:29:39 IODA_BestPath_workflow:197] ======
# [I 200821 18:29:39 IODA_BestPath_workflow:202] Best Path output found
# [I 200821 18:29:39 IODA_BestPath_workflow:211] Preparing results ...
# [I 200821 18:29:39 IODA_BestPath_workflow:213] Preparing results ...
# [I 200821 18:29:39 IODA_BestPath_workflow:563] File processed: results_targeted_pathfinder_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_PathFinder.csv
# [I 200821 18:29:39 IODA_BestPath_workflow:564] ======
# [I 200821 18:29:39 IODA_BestPath_workflow:556] Valid target ions in path1 = 404
# [I 200821 18:29:39 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:29:39 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:29:39 IODA_BestPath_workflow:579] =======
# [I 200821 18:29:39 IODA_BestPath_workflow:556] Valid target ions in path2 = 216
# [I 200821 18:29:39 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:29:39 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:29:40 IODA_BestPath_workflow:579] =======
# [I 200821 18:29:40 IODA_BestPath_workflow:556] Valid target ions in path3 = 126
# [I 200821 18:29:40 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:29:40 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:29:40 IODA_BestPath_workflow:579] =======
# [I 200821 18:29:44 IODA_BestPath_workflow:215] ======
# [I 200821 18:29:44 IODA_BestPath_workflow:217] Cleaning and zipping workflow results files ...
# [I 200821 18:29:44 IODA_BestPath_workflow:119] All files zipped successfully!
# [I 200821 18:29:44 IODA_BestPath_workflow:245] ======
# [I 200821 18:29:44 IODA_BestPath_workflow:246] END OF THE Path Finder WORKFLOW
# [I 200821 18:29:44 IODA_BestPath_workflow:247] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Apex mode

# %%
# Apex parameters
intensity_accu = 5e3

# %%
# Run Path Finder with Apex method
run_MS2Planner_apex_from_mzTab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value, intensity_accu, isolation, delay, rt_margin)
# Out:
# [I 200821 18:16:57 IODA_BestPath_workflow:262] STARTING THE PathFinder WORKFLOW
# [I 200821 18:16:57 IODA_BestPath_workflow:272] the input_filename variable should be a valid path/download link or must be: 'OpenMS_generated', when using the OpenMS workflow online
# [I 200821 18:16:57 IODA_BestPath_workflow:275] 2020-08-21 18:16:57.796839
# [I 200821 18:16:57 IODA_BestPath_workflow:277] ======
# [I 200821 18:16:57 IODA_BestPath_workflow:278] Getting the mzTab
# [I 200821 18:16:57 IODA_BestPath_workflow:294] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Blank_to_Sample_mrgd.mzTab
# [I 200821 18:16:57 IODA_BestPath_workflow:295] This is the output file path: results_targeted_pathfinder_apex/Blank_to_Sample_mrgd.csv
# [I 200821 18:16:57 IODA_BestPath_workflow:299] ======
# [I 200821 18:16:57 IODA_BestPath_workflow:300] Converting mzTab to intermediate table format ...
# [I 200821 18:16:57 IODA_BestPath_workflow:76] - For sample Blank the sum of feature intensities is = 4.33e+09
# [I 200821 18:16:57 IODA_BestPath_workflow:78] - For sample Sample the sum of feature intensities = 8.87e+09
# [I 200821 18:16:57 IODA_BestPath_workflow:302] ======
# [I 200821 18:16:57 IODA_BestPath_workflow:307] Assumed sample filename: Sample
# [I 200821 18:16:57 IODA_BestPath_workflow:309] Assumed blank filename: Blank
# [I 200821 18:16:57 IODA_BestPath_workflow:310] ======
# [I 200821 18:16:57 IODA_BestPath_workflow:313] User-defined parameters
# [I 200821 18:16:57 IODA_BestPath_workflow:315]     Ratio between sample/blank for ion filtering = 5
# [I 200821 18:16:57 IODA_BestPath_workflow:317]     Minimum intensity for ion filtering in sample = 1.00e+04
# [I 200821 18:16:57 IODA_BestPath_workflow:318]     Precursor ion intensity to accumulate in the MS2 scan = 5.00e+03
# [I 200821 18:16:57 IODA_BestPath_workflow:319]     Isolation window (m/z) = 1.5
# [I 200821 18:16:57 IODA_BestPath_workflow:320]     Retention time margin (sec.) = 0.3
# [I 200821 18:16:57 IODA_BestPath_workflow:321]     Delay between targeted MS2 scans (sec)= 0.1
# [I 200821 18:16:57 IODA_BestPath_workflow:323]     Number of iterative experiment(s) = 3
# [I 200821 18:16:57 IODA_BestPath_workflow:324] ======
# [I 200821 18:16:57 IODA_BestPath_workflow:327] Running Path Finder in Apex mode ...
# [I 200821 18:16:57 IODA_BestPath_workflow:607] Command: python3 path_finder.py apex results_targeted_pathfinder_apex/Blank_to_Sample_mrgd.csv results_targeted_pathfinder_apex/Blank_to_Sample_mrgd_PathFinder.csv 10000.0 5 3 -intensity_accu 5000.0 -isolation 1.5 -delta 0.1
# [I 200821 18:16:59 IODA_BestPath_workflow:329] ======
# [I 200821 18:16:59 IODA_BestPath_workflow:334] Best Path output found
# [I 200821 18:16:59 IODA_BestPath_workflow:344] Preparing results ...
# [I 200821 18:16:59 IODA_BestPath_workflow:563] File processed: results_targeted_pathfinder_apex/Blank_to_Sample_mrgd_PathFinder.csv
# [I 200821 18:16:59 IODA_BestPath_workflow:564] ======
# [I 200821 18:16:59 IODA_BestPath_workflow:556] Valid target ions in path1 = 365
# [I 200821 18:16:59 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:16:59 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:16:59 IODA_BestPath_workflow:579] =======
# [I 200821 18:16:59 IODA_BestPath_workflow:556] Valid target ions in path2 = 228
# [I 200821 18:16:59 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:16:59 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:16:59 IODA_BestPath_workflow:579] =======
# [I 200821 18:16:59 IODA_BestPath_workflow:556] Valid target ions in path3 = 134
# [I 200821 18:16:59 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:16:59 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:16:59 IODA_BestPath_workflow:579] =======
# [I 200821 18:17:03 IODA_BestPath_workflow:346] ======
# [I 200821 18:17:03 IODA_BestPath_workflow:348] Cleaning and zipping workflow results files ...
# [I 200821 18:17:03 IODA_BestPath_workflow:119] All files zipped successfully!
# [I 200821 18:17:03 IODA_BestPath_workflow:376] ======
# [I 200821 18:17:03 IODA_BestPath_workflow:377] END OF THE Path Finder WORKFLOW
# [I 200821 18:17:03 IODA_BestPath_workflow:378] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Curve mode

# %%
MS2Planner_Curve_OpenMS(input_SAMPLE,ppm_error,noise_level)
# Out:
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:222] 2020-08-21 18:17:04.201921
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:223] STARTING the Path Finder Curve processing
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:224] ======
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:225] Path to the input files:
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:226]     Sample: https://drive.google.com/file/d/1CoKzvreEgT0mq4JEBuB-2T0VFfoHFhZT/view?usp=sharing
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:228] ======
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:229] Download the latest version of the workflow from the repository ...
# [I 200821 18:17:04 IODA_run_OpenMS_targeted:233] wget https://github.com/lfnothias/IODA_MS/raw/MS2Planner_master/TOPPAS_Workflow/MS1_PathFinder_Curve_mzTab.toppas -O TOPPAS_Workflow/MS1_PathFinder_Curve_mzTab.toppas
# [I 200821 18:17:16 IODA_run_OpenMS_targeted:255] ======
# [I 200821 18:17:16 IODA_run_OpenMS_targeted:256] Initializing the OpenMS workflow
# [I 200821 18:17:16 IODA_run_OpenMS_targeted:264] ======
# [I 200821 18:17:16 IODA_run_OpenMS_targeted:265] Running the OpenMS workflow, this usually takes couple minutes, please wait ...
# [I 200821 18:19:33 IODA_run_OpenMS_targeted:293] ======
# [I 200821 18:19:33 IODA_run_OpenMS_targeted:294] Completed the OpenMS workflow
# [I 200821 18:19:33 IODA_run_OpenMS_targeted:295] ======
# [I 200821 18:19:33 IODA_run_OpenMS_targeted:296] Zipping up the OpenMS workflow results ..
# [I 200821 18:19:34 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 200821 18:19:34 IODA_run_OpenMS_targeted:307] ======
# [I 200821 18:19:34 IODA_run_OpenMS_targeted:308] Completed zipping up the OpenMS workflow result files
# [I 200821 18:19:34 IODA_run_OpenMS_targeted:310] ======
# [I 200821 18:19:34 IODA_run_OpenMS_targeted:311] NOW CONTINUE WITH THE REST OF THE WORKFLOW

# %%
# Curve parameters
delay = 0.1
restriction = 2 
mz_accuracy = 0.02 ### TEMPORARY NAME, SEE MY EMAIL
# Target ion list parameters
transient_time = 100 #ms

# %%
input_filename_curve = 'TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Sample.mzTab'

# %%
# Run Path Finder with Curve method
run_MS2Planner_curve_from_mzTab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value, input_filename_curve, intensity_accu, restriction, mz_accuracy, delay, rt_margin, transient_time)
# Out:
# [I 200821 18:22:07 IODA_BestPath_workflow:393] STARTING THE PathFinder WORKFLOW
# [I 200821 18:22:07 IODA_BestPath_workflow:403] the input_filename variable should be a valid path/download link or must be: 'OpenMS_generated', when using the OpenMS workflow online
# [I 200821 18:22:07 IODA_BestPath_workflow:406] 2020-08-21 18:22:07.597354
# [I 200821 18:22:07 IODA_BestPath_workflow:408] ======
# [I 200821 18:22:07 IODA_BestPath_workflow:409] Getting the mzTab
# [I 200821 18:22:07 IODA_BestPath_workflow:425] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Blank_to_Sample_mrgd.mzTab
# [I 200821 18:22:07 IODA_BestPath_workflow:426] This is the output file path: results_targeted_pathfinder_curve/Blank_to_Sample_mrgd.csv
# [I 200821 18:22:07 IODA_BestPath_workflow:429] ======
# [I 200821 18:22:07 IODA_BestPath_workflow:430] Converting mzTab to intermediate table format ...
# [I 200821 18:22:07 IODA_BestPath_workflow:76] - For sample Blank the sum of feature intensities is = 4.33e+09
# [I 200821 18:22:07 IODA_BestPath_workflow:78] - For sample Sample the sum of feature intensities = 8.87e+09
# [I 200821 18:22:07 IODA_BestPath_workflow:432] ======
# [I 200821 18:22:07 IODA_BestPath_workflow:437] Assumed sample filename: Sample
# [I 200821 18:22:07 IODA_BestPath_workflow:439] Assumed blank filename: Blank
# [I 200821 18:22:07 IODA_BestPath_workflow:440] ======
# [I 200821 18:22:07 IODA_BestPath_workflow:443] User-defined parameters
# [I 200821 18:22:07 IODA_BestPath_workflow:445]     Ratio between sample/blank for ion filtering = 5
# [I 200821 18:22:07 IODA_BestPath_workflow:447]     Minimum intensity for ion filtering in sample = 1.00e+04
# [I 200821 18:22:07 IODA_BestPath_workflow:448]     Precursor ion intensity to accumulate in the MS2 scan = 5.00e+03
# [I 200821 18:22:07 IODA_BestPath_workflow:449]     Transient time and overhead (ms) = 100
# [I 200821 18:22:07 IODA_BestPath_workflow:450]     Input file for curve data : TOPPAS_Workflow/toppas_output/TOPPAS_out/PathFinder_mzTab/Sample.mzTab
# [I 200821 18:22:07 IODA_BestPath_workflow:451]     Retention time margin (sec.) = 0.3
# [I 200821 18:22:07 IODA_BestPath_workflow:452]     Restriction parameter : 2
# [I 200821 18:22:07 IODA_BestPath_workflow:453]     Mass accuracy (m/z): 0.02
# [I 200821 18:22:07 IODA_BestPath_workflow:454]     Delay between targeted MS2 scans (sec)= 0.1
# [I 200821 18:22:07 IODA_BestPath_workflow:456]     Number of iterative experiment(s) = 3
# [I 200821 18:22:07 IODA_BestPath_workflow:457] ======
# [I 200821 18:22:07 IODA_BestPath_workflow:463] mzTab for the Curve mode found
# [I 200821 18:22:07 IODA_BestPath_workflow:473] Running PathFinder in Curve mode ...
# [I 200821 18:22:07 IODA_BestPath_workflow:612] Command: python3 path_finder.py curve results_targeted_pathfinder_curve/Blank_to_Sample_mrgd.csv results_targeted_pathfinder_curve/Blank_to_Sample_mrgd_PathFinder.csv 10000.0 5 3 -infile_raw TOPPAS_Workflow/toppas_output/TOPPAS_out/PathFinder_mzTab/Sample.mzTab -intensity_accu 5000.0 -restriction 2 0.02 -delta 0.1
# [I 200821 18:22:07 IODA_BestPath_workflow:613] Path Finder in Curve mode can take up to 10 minutes to complete ... please wait
# [I 200821 18:24:02 IODA_BestPath_workflow:482] PathFinder output found
# [I 200821 18:24:02 IODA_BestPath_workflow:491] ======
# [I 200821 18:24:02 IODA_BestPath_workflow:492] Preparing results ...
# [I 200821 18:24:02 IODA_BestPath_workflow:563] File processed: results_targeted_pathfinder_curve/Blank_to_Sample_mrgd_PathFinder.csv
# [I 200821 18:24:02 IODA_BestPath_workflow:564] ======
# [I 200821 18:24:02 IODA_BestPath_workflow:556] Valid target ions in path1 = 662
# [I 200821 18:24:02 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:24:02 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:24:02 IODA_BestPath_workflow:579] =======
# [I 200821 18:24:03 IODA_BestPath_workflow:556] Valid target ions in path2 = 163
# [I 200821 18:24:03 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:24:03 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:24:03 IODA_BestPath_workflow:579] =======
# [I 200821 18:24:03 IODA_BestPath_workflow:556] Valid target ions in path3 = 42
# [I 200821 18:24:03 IODA_BestPath_workflow:573] Formatting to XCalibur format ...
# [I 200821 18:24:03 IODA_BestPath_workflow:576] Formatting for MaxQuant.Live ...
# [I 200821 18:24:03 IODA_BestPath_workflow:579] =======
# [I 200821 18:24:07 IODA_BestPath_workflow:494] ======
# [I 200821 18:24:07 IODA_BestPath_workflow:496] Cleaning and zipping workflow results files ...
# [I 200821 18:24:07 IODA_BestPath_workflow:119] All files zipped successfully!
# [I 200821 18:24:07 IODA_BestPath_workflow:524] ======
# [I 200821 18:24:07 IODA_BestPath_workflow:525] END OF THE Path Finder WORKFLOW
# [I 200821 18:24:07 IODA_BestPath_workflow:526] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/scatter_plot_duration.png")

# %% [markdown]
# # <span style="color:red"> END OF PATH FINDER </span>
#
# **Purpose**: The IODA targeted-from-mzTab workflow takes allows to generate list of target ions for iterative optimise data acquisition (IODA) of fragmentation spectra in LC-MS. It accepts as input an mzTab file with results for two samples: the "reference" sample and the "blank" sample. The targets are detected in the "reference" sample, and background ions are detected in the "blank" sample. Background ions are excluded from the targets. The targets can be acquired by IODA in one or multiple experiments for higher coverage.
#
#
# **Usage**: This notebook requires the user to provide an mzTab. If you need to process your LC-MS data, you can use our [IODA targeted-from-mzML notebook](IODA_targeted_from_mzML.ipynb), or refer to our documentation for more informations. The IODA targeted workflow defines the target ions, and these targets are then formatted for XCalibur or [MaxQuant.Live]
#
# **Documentation**: Please refer to the documentation page [See here](link).
#
# **Instructions**: Follow the instructions below and run the notebook cells accordingly.

# %% [markdown]
# ### Step 0 - Generate an mzTab file
#
# The mzTab file must contain results from feature detection and alignment for the two samples: the "reference" sample and the "blank' sample. Please refer to the [documentation page](link) for more information.
#
# ### Step 1 - Upload the mzTab file
#
# ##### <span style="color:brown">Method 1 - Upload your mzTab file </span>
#
# Upload your mzML files on the Binder server with the Jupyter lab interface (drag-and-drop the file in the left panel or use the "Upload" icon).
#
# ##### <span style="color:brown">Method 2 - Web-sharing links</span>
# We support retrieving the files from the following cloud sharing services:
# > **Google Drive** : copy the sharing the link (make sure the sharing setting is set to 'Anyone with the link can download').
#
# > **MassIVE/GNPS repository** : copy the link for the file.
#
#
# ### Step 3 - Specify the link or path to the mzTab file
#
# In the cell below, indicate the filename for the mzTab file. The filename must be into parenthesis,  such as: *"myfile.mzTab"*. If applicable change the path, such *"input_folder/myfile.mzTab"*.

# %%
input_mzTab = 'https://drive.google.com/file/d/1NGVzhrw-xZ4nMJserIQ7v4tYgcmraZ6g/view?usp=sharing'

# %% [markdown]
# ### Step 4 - Specify the parameters of the IODA-targeted workflow
# Specify the parameter values for IODA-targeted workflow in the cell below:
#
# *min_ratio_value*: minimum ratio for the intensity of an ion/feature (peak height) between the reference and blank samples (reference/blank). Only ions above that ratio will be valid ion targets. (Default = 5).
#
# *min_intensity_value*: the minimum intensity (peak height) of an ion/feature in the reference sample to be considered as valid ion targets. (Default = 1E5).
#
# *experiment_number*: define the number of iterative experiment(s) to perform for the IODA-targeted workflow. If >2, the valid target ions will be splitted into (multiple) experiments (Default = 3, range 1-10)

# %%
min_ratio_value = 5
min_intensity_value = 1E5
experiment_number = 3

# %% [markdown]
# ### Step 5 - Run the IODA-targeted workflow
#
# Simply run the cell below to start the IODA-targeted workflow

# %%
from IODA_targeted_workflow import *
make_targeted_list_from_mzTab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value)

# %% [markdown]
# ### Step 6 - Examine the results
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid targets in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown. Verify that the OpenMS parameter variables and IODA-targeted workflows are adapted to level you want to apply, and your sample(s) complexity.
#
# - Examine the IODA-targeted worflow log and the plots in order to verify that the 'min_intensity' parameter is adapted to exclusion level you want to apply, and your sample(s) complexity.
# - Note that, at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the mzTab file (such as with TOPPAS/OpenMS).

# %%
from IPython.display import Image
Image("results_targeted/intermediate_files/experiment_blank_shared_TARGETED_RATIO_scatter_view.png")
Image("results_targeted/intermediate_files/experiment_blank_shared_TARGETED_INTENSITY_scatter_view.png")

# %% [markdown]
# ### Step 7 - Download the results
#
# Download the IODA-targeted workflow results ->
# [download-results/IODA_targeted_results.zip](download-results/IODA_targeted_results.zip?download=1).
#
# ### Step 8 - Prepare your IODA experiment
# Prepare the iterative mass spectrometry acquisition. For instructions on how to load and configure an exclusion list with XCalibur or MaxQuant.Live please refer to [the following documentation](nothing).
