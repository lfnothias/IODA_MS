# %% [markdown]
# # <span style="color:red"> MS2Planner-from-mzML notebook </span>
#
# **Purpose**: Run PathFinder in all modes
#
#
# **Usage**: Select the data and run the cells

# %% [markdown]
# # SELECT WHICH DATA YOU WANNA TRY

# %% [markdown]
# ## 1) Euphorbia data

# %%
# Blank sample
input_BLANK = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML"
# Reference sample
input_SAMPLE = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML"

#input_BLANK = 'Euphorbia_Blank_MS1_5uL.mzML'
#input_SAMPLE = 'Euphorbia_MS1_5uL.mzML'

# %% [markdown]
# ## 2) SA113 Test data

# %%
# Blank sample
input_BLANK = "tests/BP_mzTab/SA113_SPE_MeOH_MS1.mzML"
# Reference sample
input_SAMPLE = "tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1.mzML"

# %% [markdown]
# ## 3) Disolved Organic Matter via Google Drive

# %%
input_BLANK = "https://drive.google.com/file/d/10A1XZhcKCVXIKf4v7aLX0tNYM011qV_Z/view?usp=sharing"
# Reference sample
input_SAMPLE = "https://drive.google.com/file/d/1CoKzvreEgT0mq4JEBuB-2T0VFfoHFhZT/view?usp=sharing"

# %%
# OpenMS FeatureFinderMetabolomics parameters
ppm_error = 10
noise_level = 3E5

# %%
from IODA_run_OpenMS_targeted import *
IODA_targeted_workflow(input_BLANK,input_SAMPLE,ppm_error,noise_level)
# Out:
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:40] 2020-08-28 19:23:59.787300
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:41] STARTING the IODA-targeted WORKFLOW
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:42] ======
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:43] Path to the input files:
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:44] Blank: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:45] Sample: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:96] Copying the mzML files ...
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:100] ======
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:101] Changing the variables of the OpenMS workflow ...
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:102]    ppm error = 10
# [I 200828 19:23:59 IODA_run_OpenMS_targeted:103]    noise threshold = 3.00e+05
# [I 200828 19:24:04 IODA_run_OpenMS_targeted:145] ======
# [I 200828 19:24:04 IODA_run_OpenMS_targeted:146] Initializing the OpenMS workflow
# [I 200828 19:24:04 IODA_run_OpenMS_targeted:154] ======
# [I 200828 19:24:04 IODA_run_OpenMS_targeted:155] Running the OpenMS workflow, this usually takes less than a minute, please wait ...
# [I 200828 19:24:04 IODA_run_OpenMS_targeted:156] If this takes longer, increase the noise treshold value ...
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:182] ======
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:183] Completed the OpenMS workflow
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:184] ======
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:185] Zipping up the OpenMS workflow results ..
# [I 200828 19:24:27 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:188] ======
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:189] Completed zipping up the OpenMS workflow result files
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:191] ======
# [I 200828 19:24:27 IODA_run_OpenMS_targeted:192] NOW CONTINUE WITH THE REST OF THE IODA-targeted WORKFLOW

# %% [markdown]
# ## Run MS2Planner

# %%
from IODA_MS2Planner_workflow import *

# %% [markdown]
# ### Shared parameters for the modes (baseline/apex/curve)

# %%
# Best Path shared parameters
min_ratio_value = 3
min_intensity_value = 0#1E4
experiment_number = 5
isolation = 1.5
delay = 0.02 #sec

# Target ion list parameters
rt_margin = 1 #sec

# %% [markdown]
# ### MS2Planner in Baseline mode

# %%
# Baseline parameter
win_len = 0.15 #sec (duration of scan)

# %%
# Run Path Finder with Baseline method 
run_MS2Planner_baseline_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value,\
                                   min_intensity_value, win_len, isolation, delay, \
                                   rt_margin)
# Out:
# [I 200828 19:24:27 IODA_MS2Planner_workflow:131] STARTING THE MS2Planner WORKFLOW
# [I 200828 19:24:27 IODA_MS2Planner_workflow:136] The mzTab was generated with the IODA-OpenMS workflow
# [I 200828 19:24:27 IODA_MS2Planner_workflow:144] 2020-08-28 19:24:27.497084
# [I 200828 19:24:27 IODA_MS2Planner_workflow:146] ======
# [I 200828 19:24:27 IODA_MS2Planner_workflow:147] Getting the mzTab
# [I 200828 19:24:27 IODA_MS2Planner_workflow:163] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 200828 19:24:27 IODA_MS2Planner_workflow:164] This is the output file path: results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 200828 19:24:27 IODA_MS2Planner_workflow:168] ======
# [I 200828 19:24:27 IODA_MS2Planner_workflow:169] Converting mzTab to intermediate table format ...
# [I 200828 19:24:27 IODA_MS2Planner_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 6.27e+08
# [I 200828 19:24:27 IODA_MS2Planner_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.68e+10
# [I 200828 19:24:27 IODA_MS2Planner_workflow:171] ======
# [I 200828 19:24:27 IODA_MS2Planner_workflow:176] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 200828 19:24:27 IODA_MS2Planner_workflow:178] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 200828 19:24:27 IODA_MS2Planner_workflow:179] ======
# [I 200828 19:24:27 IODA_MS2Planner_workflow:182] User-defined parameters
# [I 200828 19:24:27 IODA_MS2Planner_workflow:184]     Ratio between sample/blank for ion filtering = 3
# [I 200828 19:24:27 IODA_MS2Planner_workflow:186]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 200828 19:24:27 IODA_MS2Planner_workflow:187]     Retention time window (min.) for binning target ions = 0.15
# [I 200828 19:24:27 IODA_MS2Planner_workflow:188]     Isolation window (m/z) = 1.5
# [I 200828 19:24:27 IODA_MS2Planner_workflow:189]     Retention time margin (sec.) = 0.02
# [I 200828 19:24:27 IODA_MS2Planner_workflow:191]     Number of iterative experiment(s) = 5
# [I 200828 19:24:27 IODA_MS2Planner_workflow:192] User-defined parameters for the output
# [I 200828 19:24:27 IODA_MS2Planner_workflow:193]     Retention time margin for target ion list (secs.) = 1
# [I 200828 19:24:27 IODA_MS2Planner_workflow:194] ======
# [I 200828 19:24:27 IODA_MS2Planner_workflow:197] Running MS2Planner in Baseline mode ...
# [I 200828 19:24:27 IODA_MS2Planner_workflow:688] Command: python3 path_finder.py baseline results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 5 -win_len 0.15 -isolation 1.5 -delay 0.02
# [I 200828 19:24:28 IODA_MS2Planner_workflow:213] ======
# [I 200828 19:24:28 IODA_MS2Planner_workflow:217] 2020-08-28 19:24:28,716 - path_finder - INFO - =============
#     2020-08-28 19:24:28,716 - path_finder - INFO - Baseline mode begin
#     2020-08-28 19:24:28,716 - path_finder - INFO - =============
#     2020-08-28 19:24:28,716 - path_finder - INFO - File Read
#     2020-08-28 19:24:28,716 - path_finder - INFO - =============
#     2020-08-28 19:24:28,717 - path_finder - INFO - Begin Finding Path
#     2020-08-28 19:24:28,717 - path_finder - INFO - =============
#     2020-08-28 19:24:28,767 - path_finder.baseline - INFO - [1/5]: features: 902, rest: 1842
#     2020-08-28 19:24:28,768 - path_finder.baseline - INFO - [2/5]: features: 486, rest: 1356
#     2020-08-28 19:24:28,768 - path_finder.baseline - INFO - [3/5]: features: 315, rest: 1041
#     2020-08-28 19:24:28,768 - path_finder.baseline - INFO - [4/5]: features: 215, rest: 826
#     2020-08-28 19:24:28,768 - path_finder.baseline - INFO - [5/5]: features: 153, rest: 673
#     2020-08-28 19:24:28,768 - path_finder - INFO - Paths Generated
#     2020-08-28 19:24:28,768 - path_finder - INFO - =============
#     2020-08-28 19:24:28,781 - path_finder - INFO - File Written
#     2020-08-28 19:24:28,782 - path_finder - INFO - =============
#
# [I 200828 19:24:28 IODA_MS2Planner_workflow:222] MS2Planner Path output found
# [I 200828 19:24:28 IODA_MS2Planner_workflow:231] Preparing results ...
# [I 200828 19:24:28 IODA_MS2Planner_workflow:650] File processed: results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv
# [I 200828 19:24:28 IODA_MS2Planner_workflow:651] ======
# [I 200828 19:24:29 IODA_MS2Planner_workflow:643] Valid target ions in path1 = 902
# [I 200828 19:24:29 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:29 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:29 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:29 IODA_MS2Planner_workflow:643] Valid target ions in path2 = 486
# [I 200828 19:24:29 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:29 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:29 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:30 IODA_MS2Planner_workflow:643] Valid target ions in path3 = 315
# [I 200828 19:24:30 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:30 IODA_MS2Planner_workflow:643] Valid target ions in path4 = 215
# [I 200828 19:24:30 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:30 IODA_MS2Planner_workflow:643] Valid target ions in path5 = 153
# [I 200828 19:24:30 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:30 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:30 IODA_MS2Planner_workflow:675] results_targeted_MS2Planner_baseline
# [I 200828 19:24:36 IODA_MS2Planner_workflow:234] ======
# [I 200828 19:24:36 IODA_MS2Planner_workflow:236] Cleaning and zipping workflow results files ...
# [I 200828 19:24:36 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 200828 19:24:36 IODA_MS2Planner_workflow:265] ======
# [I 200828 19:24:36 IODA_MS2Planner_workflow:266] END OF THE MS2Planner WORKFLOW
# [I 200828 19:24:36 IODA_MS2Planner_workflow:267] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Apex mode

# %%
# Apex parameters
intensity_accu = 5e4
min_scan = 0.1
max_scan = 0.5

rt_margin = 1
transient_time = 80 #msec

# %%
# Run Path Finder with Apex method
run_MS2Planner_apex_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, intensity_accu, isolation, delay, min_scan, max_scan, rt_margin, transient_time)
# Out:
# [I 200828 19:24:40 IODA_MS2Planner_workflow:282] STARTING THE MS2Planner WORKFLOW
# [I 200828 19:24:40 IODA_MS2Planner_workflow:287] The mzTab was generated with the IODA-OpenMS workflow
# [I 200828 19:24:40 IODA_MS2Planner_workflow:295] 2020-08-28 19:24:40.708056
# [I 200828 19:24:40 IODA_MS2Planner_workflow:297] ======
# [I 200828 19:24:40 IODA_MS2Planner_workflow:298] Getting the mzTab
# [I 200828 19:24:40 IODA_MS2Planner_workflow:314] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 200828 19:24:40 IODA_MS2Planner_workflow:315] This is the output file path: results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 200828 19:24:40 IODA_MS2Planner_workflow:319] ======
# [I 200828 19:24:40 IODA_MS2Planner_workflow:320] Converting mzTab to intermediate table format ...
# [I 200828 19:24:40 IODA_MS2Planner_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 6.27e+08
# [I 200828 19:24:40 IODA_MS2Planner_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.68e+10
# [I 200828 19:24:40 IODA_MS2Planner_workflow:322] ======
# [I 200828 19:24:40 IODA_MS2Planner_workflow:327] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 200828 19:24:40 IODA_MS2Planner_workflow:329] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 200828 19:24:40 IODA_MS2Planner_workflow:330] ======
# [I 200828 19:24:40 IODA_MS2Planner_workflow:333] User-defined parameters
# [I 200828 19:24:40 IODA_MS2Planner_workflow:335]     Ratio between sample/blank for ion filtering = 3
# [I 200828 19:24:40 IODA_MS2Planner_workflow:337]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 200828 19:24:40 IODA_MS2Planner_workflow:338]     Precursor ion intensity to accumulate in the MS2 scan = 5.00e+04
# [I 200828 19:24:40 IODA_MS2Planner_workflow:339]     Isolation window (m/z) = 1.5
# [I 200828 19:24:40 IODA_MS2Planner_workflow:340]     Delay between targeted MS2 scans (sec.)= 0.02
# [I 200828 19:24:40 IODA_MS2Planner_workflow:341]     Minimum MS2 scan duty cycle (sec.)= 0.1
# [I 200828 19:24:40 IODA_MS2Planner_workflow:342]     Maximum MS2 scan duty cycle (sec.)= 0.5
# [I 200828 19:24:40 IODA_MS2Planner_workflow:344]     Number of iterative experiment(s) = 5
# [I 200828 19:24:40 IODA_MS2Planner_workflow:345] User-defined parameters for the output
# [I 200828 19:24:40 IODA_MS2Planner_workflow:346]     Retention time margin for target ion list (secs.) = 1
# [I 200828 19:24:40 IODA_MS2Planner_workflow:347]     Orbitrap transient + overhead time for MaxQuant.Live (secs) = 80
# [I 200828 19:24:40 IODA_MS2Planner_workflow:349] ======
# [I 200828 19:24:40 IODA_MS2Planner_workflow:352] Running MS2Planner in Apex mode ...
# [I 200828 19:24:40 IODA_MS2Planner_workflow:693] Command: python3 path_finder.py apex results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 5 -intensity_accu 50000.0 -isolation 1.5 -delay 0.02 -min_scan 0.1 -max_scan 0.5
# [I 200828 19:24:42 IODA_MS2Planner_workflow:369] ======
# [I 200828 19:24:42 IODA_MS2Planner_workflow:373] 2020-08-28 19:24:41,978 - path_finder - INFO - =============
#     2020-08-28 19:24:41,978 - path_finder - INFO - Apex mode begin
#     2020-08-28 19:24:41,978 - path_finder - INFO - =============
#     2020-08-28 19:24:41,978 - path_finder - INFO - File Read
#     2020-08-28 19:24:41,978 - path_finder - INFO - =============
#     2020-08-28 19:24:41,979 - path_finder - INFO - Begin Finding Path
#     2020-08-28 19:24:41,979 - path_finder - INFO - =============
#     2020-08-28 19:24:42,043 - path_finder.apex - INFO - [1/5]: features: 714, rest: 2744
#     2020-08-28 19:24:42,083 - path_finder.apex - INFO - [2/5]: features: 440, rest: 2030
#     2020-08-28 19:24:42,121 - path_finder.apex - INFO - [3/5]: features: 302, rest: 1590
#     2020-08-28 19:24:42,139 - path_finder.apex - INFO - [4/5]: features: 232, rest: 1288
#     2020-08-28 19:24:42,152 - path_finder.apex - INFO - [5/5]: features: 174, rest: 1056
#     2020-08-28 19:24:42,154 - path_finder - INFO - Paths Generated
#     2020-08-28 19:24:42,154 - path_finder - INFO - =============
#     2020-08-28 19:24:42,176 - path_finder - INFO - File Written
#     2020-08-28 19:24:42,177 - path_finder - INFO - =============
#
# [I 200828 19:24:42 IODA_MS2Planner_workflow:375] ======
# [I 200828 19:24:42 IODA_MS2Planner_workflow:380] MS2Planner output found
# [I 200828 19:24:42 IODA_MS2Planner_workflow:390] Preparing results ...
# [I 200828 19:24:42 IODA_MS2Planner_workflow:650] File processed: results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv
# [I 200828 19:24:42 IODA_MS2Planner_workflow:651] ======
# [I 200828 19:24:42 IODA_MS2Planner_workflow:643] Valid target ions in path1 = 714
# [I 200828 19:24:42 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:42 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:42 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:43 IODA_MS2Planner_workflow:643] Valid target ions in path2 = 440
# [I 200828 19:24:43 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:43 IODA_MS2Planner_workflow:643] Valid target ions in path3 = 302
# [I 200828 19:24:43 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:43 IODA_MS2Planner_workflow:643] Valid target ions in path4 = 232
# [I 200828 19:24:43 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:43 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:43 IODA_MS2Planner_workflow:643] Valid target ions in path5 = 174
# [I 200828 19:24:44 IODA_MS2Planner_workflow:660] Formatting to XCalibur format ...
# [I 200828 19:24:44 IODA_MS2Planner_workflow:663] Formatting for MaxQuant.Live ...
# [I 200828 19:24:44 IODA_MS2Planner_workflow:666] =======
# [I 200828 19:24:44 IODA_MS2Planner_workflow:675] results_targeted_MS2Planner_apex
# [I 200828 19:24:49 IODA_MS2Planner_workflow:392] ======
# [I 200828 19:24:49 IODA_MS2Planner_workflow:394] Cleaning and zipping workflow results files ...
# [I 200828 19:24:49 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 200828 19:24:49 IODA_MS2Planner_workflow:423] ======
# [I 200828 19:24:49 IODA_MS2Planner_workflow:424] END OF THE MS2Planner WORKFLOW
# [I 200828 19:24:49 IODA_MS2Planner_workflow:425] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Curve mode

# %%
MS2Planner_Curve_OpenMS(input_SAMPLE)
# Out:
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:222] 2020-08-28 19:26:18.988599
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:223] STARTING the MS2Planner Curve processing
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:224] ======
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:225] Path to the input files:
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:226]     Sample: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 200828 19:26:18 IODA_run_OpenMS_targeted:228] ======
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:229] Download the latest version of the workflow from the repository ...
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:233] wget https://github.com/lfnothias/IODA_MS/raw/MS2Planner_merge_w_master/TOPPAS_Workflow/MS1_MS2Planner_Curve_mzTab.toppas -O TOPPAS_Workflow/MS1_MS2Planner_Curve_mzTab.toppas
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:255] ======
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:256] Initializing the OpenMS workflow
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:264] ======
# [I 200828 19:26:19 IODA_run_OpenMS_targeted:265] Running the OpenMS workflow, this usually takes couple minutes, please wait ...
# [I 200828 19:27:46 IODA_run_OpenMS_targeted:293] ======
# [I 200828 19:27:46 IODA_run_OpenMS_targeted:294] Completed the OpenMS workflow
# [I 200828 19:27:46 IODA_run_OpenMS_targeted:295] ======
# [I 200828 19:27:46 IODA_run_OpenMS_targeted:296] Zipping up the OpenMS workflow results ..
# [I 200828 19:27:47 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 200828 19:27:47 IODA_run_OpenMS_targeted:307] ======
# [I 200828 19:27:47 IODA_run_OpenMS_targeted:308] Completed zipping up the OpenMS workflow result files
# [I 200828 19:27:47 IODA_run_OpenMS_targeted:310] ======
# [I 200828 19:27:47 IODA_run_OpenMS_targeted:311] NOW CONTINUE WITH THE REST OF THE WORKFLOW

# %%
# Curve parameters
rt_tolerance_curve = 2 
mz_tolerance_curve = 0.02
intensity_accu = 1e6
curve = 'kNN'

# %%
# Run Path Finder with Curve method
from IODA_MS2Planner_workflow import *
run_MS2Planner_curve_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, 'OpenMS_generated', intensity_accu, rt_tolerance_curve, mz_tolerance_curve, isolation, delay, min_scan, max_scan, curve, rt_margin, transient_time)
# Out:
# [I 200828 19:28:28 IODA_MS2Planner_workflow:441] STARTING THE MS2Planner WORKFLOW
# [I 200828 19:28:28 IODA_MS2Planner_workflow:446] The mzTab was generated with the IODA-OpenMS workflow
# [I 200828 19:28:28 IODA_MS2Planner_workflow:454] 2020-08-28 19:28:28.289323
# [I 200828 19:28:28 IODA_MS2Planner_workflow:456] ======
# [I 200828 19:28:28 IODA_MS2Planner_workflow:457] Getting the mzTab
# [I 200828 19:28:28 IODA_MS2Planner_workflow:473] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 200828 19:28:28 IODA_MS2Planner_workflow:474] This is the output file path: results_targeted_MS2Planner_curve/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 200828 19:28:28 IODA_MS2Planner_workflow:482] TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Euphorbia_rogers_latex_latex_MS1_2uL.mzTab
# [I 200828 19:28:28 IODA_MS2Planner_workflow:484] mzTab for the Curve mode found in the OpenMS folder at:
# [I 200828 19:28:28 IODA_MS2Planner_workflow:485] TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Euphorbia_rogers_latex_latex_MS1_2uL.mzTab
# [I 200828 19:28:28 IODA_MS2Planner_workflow:501] ======
# [I 200828 19:28:28 IODA_MS2Planner_workflow:502] Converting mzTab to intermediate table format ...
# [I 200828 19:28:28 IODA_MS2Planner_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 6.27e+08
# [I 200828 19:28:28 IODA_MS2Planner_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.68e+10
# [I 200828 19:28:28 IODA_MS2Planner_workflow:504] ======
# [I 200828 19:28:28 IODA_MS2Planner_workflow:509] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 200828 19:28:28 IODA_MS2Planner_workflow:511] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 200828 19:28:28 IODA_MS2Planner_workflow:512] Sample for the Curve mode: TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Euphorbia_rogers_latex_latex_MS1_2uL.mzTab
# [I 200828 19:28:28 IODA_MS2Planner_workflow:513] ======
# [I 200828 19:28:28 IODA_MS2Planner_workflow:517] User-defined parameters for MS2Planner
# [I 200828 19:28:28 IODA_MS2Planner_workflow:519]     Ratio between sample/blank for ion filtering = 3
# [I 200828 19:28:28 IODA_MS2Planner_workflow:521]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 200828 19:28:28 IODA_MS2Planner_workflow:522]     Precursor ion intensity to accumulate in the MS2 scan = 5.00e+04
# [I 200828 19:28:28 IODA_MS2Planner_workflow:523]     Input file for curve data : OpenMS_generated
# [I 200828 19:28:28 IODA_MS2Planner_workflow:524]     Restriction parameter : 2
# [I 200828 19:28:28 IODA_MS2Planner_workflow:525]     Mass accuracy (m/z): 0.02
# [I 200828 19:28:28 IODA_MS2Planner_workflow:526]     Isolation window (m/z) = 1.5
# [I 200828 19:28:28 IODA_MS2Planner_workflow:527]     Delay between targeted MS2 scans (sec.)= 0.02
# [I 200828 19:28:28 IODA_MS2Planner_workflow:528]     Minimum MS2 scan duty cycle (sec.)= 0.1
# [I 200828 19:28:28 IODA_MS2Planner_workflow:529]     Maximum MS2 scan duty cycle (sec.)= 0.5
# [I 200828 19:28:28 IODA_MS2Planner_workflow:531]     Number of iterative experiment(s) = 5
# [I 200828 19:28:28 IODA_MS2Planner_workflow:532]     Mode for the curve mode: kNN
# [I 200828 19:28:28 IODA_MS2Planner_workflow:533] User-defined parameters for the output
# [I 200828 19:28:28 IODA_MS2Planner_workflow:534]     Retention time margin for target ion list (secs.) = 1
# [I 200828 19:28:28 IODA_MS2Planner_workflow:535]     Orbitrap transient + overhead time for MaxQuant.Live (secs) = 80
# [I 200828 19:28:28 IODA_MS2Planner_workflow:536] ======
# [I 200828 19:28:28 IODA_MS2Planner_workflow:539] Running MS2Planner in Curve mode ...
# [I 200828 19:28:28 IODA_MS2Planner_workflow:698] Command: python3 path_finder.py curve results_targeted_MS2Planner_curve/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_curve/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 5 -infile_raw TOPPAS_Workflow/toppas_output/TOPPAS_out/MS2Planner_mzTab/Euphorbia_rogers_latex_latex_MS1_2uL.mzTab -intensity_accu 50000.0 -restriction 2 0.02 -isolation 1.5 -delay 0.02 -min_scan 0.1 -max_scan 0.5 -cluster kNN
# [I 200828 19:28:28 IODA_MS2Planner_workflow:699] MS2Planner in Curve mode can take up to 10 minutes to complete ... please wait

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/scatter_plot_duration.png")
